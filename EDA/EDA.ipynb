# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
tips=sns.load_dataset("tips")
# Out:
# cannot find symbol
#   symbol:   variable tips
# tips=sns.load_dataset("tips")
# ^--^
# cannot find symbol
#   symbol:   variable sns
# tips=sns.load_dataset("tips")
#      ^-^
